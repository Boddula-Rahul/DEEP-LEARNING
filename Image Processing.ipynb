# %%
pip install opencv-python

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\pc\Desktop\india.jpg")

# %%
img
# Out:
# array([[[117, 163, 189],
#         [117, 163, 189],
#         [117, 163, 189],
#         ...,
#         [111, 164, 189],
#         [111, 164, 189],
#         [111, 164, 189]],
#
#        [[117, 163, 189],
#         [117, 163, 189],
#         [117, 163, 189],
#         ...,
#         [111, 164, 189],
#         [111, 164, 189],
#         [111, 164, 189]],
#
#        [[117, 163, 189],
#         [117, 163, 189],
#         [117, 163, 189],
#         ...,
#         [111, 164, 189],
#         [111, 164, 189],
#         [111, 164, 189]],
#
#        ...,
#
#        [[255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1],
#         ...,
#         [255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1]],
#
#        [[255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1],
#         ...,
#         [255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1]],
#
#        [[255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1],
# ...

# %%
plt.imshow(img)

# %%
cv2.imshow("INDIA Window",img)
cv2.waitKey(-1)
# Out:
# -1

# %%
rabbit = cv2.imread(r"C:\Users\pc\Desktop\rabbit.jpg")

# %%
rabbit
# Out:
# array([[[ 58, 109, 101],
#         [ 57, 108, 100],
#         [ 55, 106,  98],
#         ...,
#         [ 73, 130, 109],
#         [ 73, 125, 107],
#         [ 71, 123, 105]],
#
#        [[ 66, 119, 110],
#         [ 65, 118, 109],
#         [ 62, 115, 106],
#         ...,
#         [ 71, 128, 107],
#         [ 72, 124, 106],
#         [ 70, 122, 104]],
#
#        [[ 71, 131, 121],
#         [ 69, 129, 119],
#         [ 69, 126, 117],
#         ...,
#         [ 68, 125, 104],
#         [ 70, 123, 103],
#         [ 68, 121, 101]],
#
#        ...,
#
#        [[103, 124,  92],
#         [106, 127,  95],
#         [106, 127,  95],
#         ...,
#         [ 25,  42,  28],
#         [ 16,  33,  22],
#         [  8,  25,  14]],
#
#        [[112, 130,  99],
#         [117, 135, 104],
#         [117, 136, 103],
#         ...,
#         [ 24,  41,  28],
#         [ 21,  38,  29],
#         [ 12,  31,  22]],
#
#        [[116, 134, 103],
#         [122, 140, 109],
#         [120, 139, 106],
# ...

# %%
cv2.imshow("Window", rabbit)
cv2.waitKey(-1)
# Out:
# -1

# %% [markdown]
# ### Gray Scale

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img_gray
# Out:
# array([[166, 166, 166, ..., 165, 165, 165],
#        [166, 166, 166, ..., 165, 165, 165],
#        [166, 166, 166, ..., 165, 165, 165],
#        ...,
#        [133, 133, 133, ..., 133, 133, 133],
#        [133, 133, 133, ..., 133, 133, 133],
#        [133, 133, 133, ..., 133, 133, 133]], dtype=uint8)

# %%
cv2.imshow("Window", img_gray)
cv2.waitKey(-1)
# Out:
# -1

# %%
img
# Out:
# array([[[117, 163, 189],
#         [117, 163, 189],
#         [117, 163, 189],
#         ...,
#         [111, 164, 189],
#         [111, 164, 189],
#         [111, 164, 189]],
#
#        [[117, 163, 189],
#         [117, 163, 189],
#         [117, 163, 189],
#         ...,
#         [111, 164, 189],
#         [111, 164, 189],
#         [111, 164, 189]],
#
#        [[117, 163, 189],
#         [117, 163, 189],
#         [117, 163, 189],
#         ...,
#         [111, 164, 189],
#         [111, 164, 189],
#         [111, 164, 189]],
#
#        ...,
#
#        [[255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1],
#         ...,
#         [255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1]],
#
#        [[255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1],
#         ...,
#         [255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1]],
#
#        [[255, 177,   1],
#         [255, 177,   1],
#         [255, 177,   1],
# ...

# %%
cv2.imshow("window",img)
cv2.waitKey(0)
# Out:
# -1

# %%
img.shape
# Out:
# (932, 850, 3)

# %%
rabbit.shape
# Out:
# (512, 512, 3)

# %%
img_gray.shape
# Out:
# (932, 850)

# %%
img[  :,   :,0 ] = 0

# %%
cv2.imshow("Red Zero", img)
cv2.waitKey(-1)
# Out:
# -1

# %%
img1 = cv2.imread(r"C:\Users\pc\Desktop\india.jpg")

# %%
cv2.imshow("window",img1)
cv2.waitKey(-1)
# Out:
# -1

# %%
img0 = img1.copy()

# %%
img0[ :, :, 0] = 0

# %%
cv2.imshow("Red Zero",img0)
cv2.waitKey(-1)
# Out:
# -1

# %%
img_one = img1.copy()

# %%
img_one[ :,  :, 1] = 0

# %%
cv2.imshow("Green Zero",img_one)
cv2.waitKey(-1)
# Out:
# -1

# %%
img_two = img1.copy()

# %%
img_two[ :, :, 2] = 0

# %%
cv2.imshow("Blue Zero",img_two)
cv2.waitKey(-1)

# %%
import pandas as pd

# %%
import numpy as np

# %%
new = np.hstack((img0,img_one,img_two))

# %%
cv2.imshow("NEW IMAGE", new)
cv2.waitKey(-1)

# %%
cv2.imshow("rabbit", rabbit)
cv2.waitKey(-1)
# Out:
# -1

# %%
rabbit

# %%
rabbit.shape

# %%
rabbit_red = rabbit.copy()

# %%
rabbit_green = rabbit.copy()

# %%
rabbit_blue = rabbit.copy()

# %%
rabbit_red[ :, :, 0] = 0

# %%
cv2.imshow("Red rabbit", rabbit_red)
cv2.waitKey(-1)
# Out:
# -1

# %%
rabbit_green[ :, :, 1] = 1

# %%
cv2.imshow("green rabbit", rabbit_green)
cv2.waitKey(-1)
# Out:
# -1

# %%
rabbit_blue[ :, :, 2] = 2

# %%
cv2.imshow("blue rabbit", rabbit_blue)
cv2.waitKey(-1)
# Out:
# -1

# %%
all = np.hstack(( rabbit_red,rabbit_green,rabbit_blue))

# %%
cv2.imshow("ALL", all)
cv2.waitKey(-1)
# Out:
# -1
